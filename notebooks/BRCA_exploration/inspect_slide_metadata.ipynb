# %%
import openslide

# %% [markdown]
# ### Find the micron/pixel for train and test set so testing is at same level as train...

# %%
# slide_file_path = "/local_storage/BRCA_blind_test/SZ9480_22-6-3-1.mrxs"
slide_file_path = "/tank/WSI_data/Ovarian_WSIs/UBC-OCEAN/train_images/40503.png"
slide = openslide.open_slide(slide_file_path)
# Out:
# ---------------------------------------------------------------------------
# OpenSlideUnsupportedFormatError           Traceback (most recent call last)
# ~/anaconda3/envs/clam/lib/python3.7/site-packages/openslide/__init__.py in open_slide(filename)
#     429     try:
# --> 430         return OpenSlide(filename)
#     431     except OpenSlideUnsupportedFormatError:
#
# ~/anaconda3/envs/clam/lib/python3.7/site-packages/openslide/__init__.py in __init__(self, filename)
#     165         self._filename = filename
# --> 166         self._osr = lowlevel.open(str(filename))
#     167
#
# ~/anaconda3/envs/clam/lib/python3.7/site-packages/openslide/lowlevel.py in _check_open(result, _func, _args)
#     194     if result is None:
# --> 195         raise OpenSlideUnsupportedFormatError("Unsupported or missing image file")
#     196     slide = _OpenSlide(c_void_p(result))
#
# OpenSlideUnsupportedFormatError: Unsupported or missing image file
#
# ...

# %%
# Get slide properties/metadata
slide_properties = slide.properties

# Access the magnification metadata

# Iterate through all property keys and values
for key, value in slide_properties.items():
    print(f"Property Key: {key}")
    print(f"Property Value: {value}")
    print("-" * 40)



    "mpp-x" # check all smame for different slides in train and test.... then get comparason to 20x.... 0.242797397769517 mpp for level 0.  TCGA--? 0.504 micro per pixel...
# Close the slide when done
slide.close()


# TODO: plot two patches to check visually..
# Out:
# Property Key: openslide.comment
# Property Value:
# ----------------------------------------
# Property Key: openslide.level-count
# Property Value: 10
# ----------------------------------------
# Property Key: openslide.level[0].downsample
# Property Value: 1
# ----------------------------------------
# Property Key: openslide.level[0].height
# Property Value: 43898
# ----------------------------------------
# Property Key: openslide.level[0].tile-height
# Property Value: 128
# ----------------------------------------
# Property Key: openslide.level[0].tile-width
# Property Value: 128
# ----------------------------------------
# Property Key: openslide.level[0].width
# Property Value: 59760
# ----------------------------------------
# Property Key: openslide.level[1].downsample
# Property Value: 2
# ----------------------------------------
# Property Key: openslide.level[1].height
# Property Value: 21949
# ----------------------------------------
# ...
